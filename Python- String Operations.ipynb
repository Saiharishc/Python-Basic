# %%
import pandas as pd
import numpy as np
df= pd.read_csv('C:\\Users\\Sai\\Downloads\\Udemy_Python\\datacode\\carprice.csv')
df
# Out:
#       car_id  price  Kilometers   hp  Brand Sport  age  Users    gas  \
# 0       3548  48750         NaN  110      6   YES    7      1  590.0
# 1        903  16610         NaN  110      3    NO    8      1  391.0
# 2       3903  27100      3040.0  110      2   YES    8      1  478.0
# 3       5098  24240      4690.0  110      5    NO    8      1    NaN
# 4       3364  13030      5820.0  110      5    NO    9      1    NaN
# 5       2854  13940    106710.0  110      6    NO    9      1  357.0
# 6       4187  22190      8610.0  110      4    NO    9      1  360.0
# 7        460  51300     11040.0  192      3    NO    9      1  380.0
# 8       3587  35050     12720.0  192      5   YES   10      2  617.0
# 9       1880  17290     11490.0  110      2    NO    9      2  382.0
# 10      2129  14000     12180.0  110      5    NO    9      1  323.0
# 11      3885  82540     17700.0  192      6    NO   10      1  323.0
# 12      1341  19840     15330.0  110      1   YES    9      1  575.0
# ...

# %%
df['Sport'][0:5]
# Out:
# 0    YES
# 1     NO
# 2    YES
# 3     NO
# 4     NO
# Name: Sport, dtype: object

# %%
df['Sport'][0:5].str.extract('(\w+)')   #Extract first word from the column
# Out:
#      0
# 0  YES
# 1   NO
# 2  YES
# 3   NO
# 4   NO

# %%
#df['Sport'][0:5].str.extract('(\w+)\s(\w+)')                Will extract first two words

# %%
df[df['Sport']=='YES']   #filter rows
# Out:
#       car_id  price  Kilometers   hp  Brand Sport  age  Users    gas  \
# 0       3548  48750         NaN  110      6   YES    7      1  590.0
# 2       3903  27100      3040.0  110      2   YES    8      1  478.0
# 8       3587  35050     12720.0  192      5   YES   10      2  617.0
# 12      1341  19840     15330.0  110      1   YES    9      1  575.0
# 16        60  12690     21020.0   90      2   YES   10      1  587.0
# 20      2097  14690     17770.0  110      6   YES   12      1  543.0
# 21      1320  12500     25180.0  192      2   YES   11      1  473.0
# 22       557  12160     22290.0  192      1   YES   11      1  623.0
# 25      1179  13540     25990.0   90      4   YES   13      1  647.0
# 28      4882  19210     22490.0  192      2   YES   10      1  451.0
# 31       540  22050     23380.0  192      2   YES   13      1  475.0
# 32      4355  52440     23580.0  192      3   YES   13      1  516.0
# 33      2352  59730     26090.0  192      4   YES   13      1  464.0
# ...

# %%
df['Sport'][0:5].str.lower()  #convert to lower case
df['Sport'][0:5].str.upper()  #convert to uppercase
# Out:
# 0    YES
# 1     NO
# 2    YES
# 3     NO
# 4     NO
# Name: Sport, dtype: object

# %%
df['Sport'][0:5].str.len()     #to identify length of each element
# Out:
# 0    3
# 1    2
# 2    3
# 3    2
# 4    2
# Name: Sport, dtype: int64

# %%
#df['Sport'][0:5].str.split(' ')       #Usually splits based on whitespace

# %%
df['Sport'][0:5].str.replace('YES','S')
# Out:
# 0     S
# 1    NO
# 2     S
# 3    NO
# 4    NO
# Name: Sport, dtype: object

# %%
df.columns
# Out:
# Index(['car_id', 'price', 'Kilometers', 'hp', 'Brand', 'Sport', 'age', 'Users',
#        'gas', 'Metalilic', 'CC', 'Weight', 'QuartTax', 'Automatic', 'red',
#        'Owner_gender', 'door'],
#       dtype='object')

# %%
#Merging
p1=df[['car_id','price']][0:2]
p2=df[['car_id','price']][0:5]
pd.concat([p1,p2])
# Out:
#    car_id  price
# 0    3548  48750
# 1     903  16610
# 0    3548  48750
# 1     903  16610
# 2    3903  27100
# 3    5098  24240
# 4    3364  13030

# %%
concatenated=pd.concat([p1,p2],keys=['p1','p2'])  #difference can be identified by keys
concatenated
# Out:
#       car_id  price
# p1 0    3548  48750
#    1     903  16610
# p2 0    3548  48750
#    1     903  16610
#    2    3903  27100
#    3    5098  24240
#    4    3364  13030

# %%
#concatenated.ix('p1')  #extracted back from concatenated data
